# %%
import os
import shutil

# %%
os.chdir(r"\\umcfs059\TILdata$\TIL Students\Iris\Results")

# %%
import glob

# %%
filelist = glob.glob("*.tif")

# %%
for item in filelist:
    name = item.split(".")[0]
    shutil.move(item, name+"\\")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\Anaconda3\lib\shutil.py in move(src, dst, copy_function)
#     543     try:
# --> 544         os.rename(src, real_dst)
#     545     except OSError:
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'B4GALT1_UNT_003_cell1.tif' -> 'B4GALT1_UNT_003_cell1\\B4GALT1_UNT_003_cell1.tif'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-9-1ff5e619255c> in <module>()
#       1 for item in filelist:
#       2     name = item.split(".")[0]
# ----> 3     shutil.move(item, name+"\\"+item)
#
# ~\Anaconda3\lib\shutil.py in move(src, dst, copy_function)
#     556             rmtree(src)
#     557         else:
# --> 558             copy_function(src, real_dst)
#     559             os.unlink(src)
# ...

# %%
filelist[0]
# Out:
# 'B4GALT1_UNT_003_cell1.tif'

# %%
path = r"\\umcfs059\TILdata$\TIL Students\Iris\Results"

# %%
path
# Out:
# '\\\\umcfs059\\TILdata$\\TIL Students\\Iris\\Results'

# %%
import re

# %%
files = os.listdir(path)

# %%
for f in files:
    if re.search(".tif$", f):
        name = f.split(".")[0]
        #print(type(name))
        src = path + "\\" + f
        #print(src)
        dest = path + "\\" + name + "\\" + f
        print(dest)
        shutil.move(src, dest)
# Out:
# \\umcfs059\TILdata$\TIL Students\Iris\Results\B4GALT1_UNT_003_cell1\B4GALT1_UNT_003_cell1.tif
# \\umcfs059\TILdata$\TIL Students\Iris\Results\B4GALT1_UNT_003_cell2\B4GALT1_UNT_003_cell2.tif
# \\umcfs059\TILdata$\TIL Students\Iris\Results\B4GALT1_UNT_003_cell3\B4GALT1_UNT_003_cell3.tif
# \\umcfs059\TILdata$\TIL Students\Iris\Results\B4GALT1_UNT_003_cell4\B4GALT1_UNT_003_cell4.tif
# \\umcfs059\TILdata$\TIL Students\Iris\Results\B4GALT1_UNT_003_cell5\B4GALT1_UNT_003_cell5.tif
# \\umcfs059\TILdata$\TIL Students\Iris\Results\B4GALT1_UNT_003_cell6\B4GALT1_UNT_003_cell6.tif
# \\umcfs059\TILdata$\TIL Students\Iris\Results\B4GALT1_UNT_004_cell1\B4GALT1_UNT_004_cell1.tif
# \\umcfs059\TILdata$\TIL Students\Iris\Results\B4GALT1_UNT_004_cell2\B4GALT1_UNT_004_cell2.tif
# \\umcfs059\TILdata$\TIL Students\Iris\Results\B4GALT1_UNT_004_cell3\B4GALT1_UNT_004_cell3.tif
# \\umcfs059\TILdata$\TIL Students\Iris\Results\B4GALT1_UNT_004_cell4\B4GALT1_UNT_004_cell4.tif
# ...
